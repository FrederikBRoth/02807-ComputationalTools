# %% [markdown]
# ## This is the assignments for 1.
# 1.1.1 - Hello world

# %%
for _ in range(10):
    print("Hdllo, world!")

# %% [markdown]
# 1.1.6 - useargument modif

# %%
import sys
name1 = input()
name2 = input()
name3 = input()
print(name1, name2, name3)
